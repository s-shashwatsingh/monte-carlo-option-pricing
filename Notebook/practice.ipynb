# %%
import sys
print(sys.executable)
# Out:
# /Users/shashwatsingh/python_projects/learning_python/venv/bin/python

# %%
import sys
print(sys.executable)
# Out:
# /Users/shashwatsingh/python_projects/learning_python/venv/bin/python

# %%
import yfinance as yf
print("yfinance is working")
# Out:
# yfinance is working
